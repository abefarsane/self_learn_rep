# %%
import pandas

# %%
df1 = pandas.read_csv("supermarkets.csv")

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1["Total data"] = df1.shape[1]

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                                            Employees  Total data
# 0  Madeira, 0     8\n1    15\n2    25\n3    10\n4...           7
# 1  Bready Shop, 0     8\n1    15\n2    25\n3    1...           7
# 2  Super River, 0     8\n1    15\n2    25\n3    1...           7
# 3  Ben's Shop, 0     8\n1    15\n2    25\n3    10...           7
# 4  Sanchez, 0     8\n1    15\n2    25\n3    10\n4...           7
# ...

# %%
df1.shape[1]
# Out:
# 8

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                                            Employees  Total data
# 0  Madeira, 0     8\n1    15\n2    25\n3    10\n4...           7
# 1  Bready Shop, 0     8\n1    15\n2    25\n3    1...           7
# 2  Super River, 0     8\n1    15\n2    25\n3    1...           7
# 3  Ben's Shop, 0     8\n1    15\n2    25\n3    10...           7
# 4  Sanchez, 0     8\n1    15\n2    25\n3    10\n4...           7
# ...

# %%
df1.drop("Address",1)
# Out:
#    ID           City             State Country         Name  \
# 0   1  San Francisco          CA 94114     USA      Madeira
# 1   2  San Francisco          CA 94119     USA  Bready Shop
# 2   3  San Francisco  California 94114     USA  Super River
# 3   4  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  San Francisco        California     USA      Sanchez
# 5   6  San Francisco          CA 94114     USA   Richvalley
#
#                                            Employees  Total data
# 0  Madeira, 0     8\n1    15\n2    25\n3    10\n4...           7
# 1  Bready Shop, 0     8\n1    15\n2    25\n3    1...           7
# 2  Super River, 0     8\n1    15\n2    25\n3    1...           7
# 3  Ben's Shop, 0     8\n1    15\n2    25\n3    10...           7
# 4  Sanchez, 0     8\n1    15\n2    25\n3    10\n4...           7
# 5  Richvalley, 0     8\n1    15\n2    25\n3    10...           7

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                                            Employees  Total data
# 0  Madeira, 0     8\n1    15\n2    25\n3    10\n4...           7
# 1  Bready Shop, 0     8\n1    15\n2    25\n3    1...           7
# 2  Super River, 0     8\n1    15\n2    25\n3    1...           7
# 3  Ben's Shop, 0     8\n1    15\n2    25\n3    10...           7
# 4  Sanchez, 0     8\n1    15\n2    25\n3    10\n4...           7
# ...

# %%
df1.drop(df1.iloc[0,])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-f26427bf8af8> in <module>
# ----> 1 df1.drop(df1.iloc[0,])
#
# c:\users\abefa\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# c:\users\abefa\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df1.T
# Out:
#                                                             0  \
# ID                                                          1
# Address                                          3666 21st St
# City                                            San Francisco
# State                                                CA 94114
# Country                                                   USA
# Name                                                  Madeira
# Employees   Madeira, 0     8\n1    15\n2    25\n3    10\n4...
# Total data                                                  7
#
#                                                             1  \
# ID                                                          2
# Address                                        735 Dolores St
# City                                            San Francisco
# State                                                CA 94119
# Country                                                   USA
# ...

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                                            Employees  Total data
# 0  Madeira, 0     8\n1    15\n2    25\n3    10\n4...           7
# 1  Bready Shop, 0     8\n1    15\n2    25\n3    1...           7
# 2  Super River, 0     8\n1    15\n2    25\n3    1...           7
# 3  Ben's Shop, 0     8\n1    15\n2    25\n3    10...           7
# 4  Sanchez, 0     8\n1    15\n2    25\n3    10\n4...           7
# ...

# %%
df1_t = df1.T

# %%
df1_t
# Out:
#                                                             0  \
# ID                                                          1
# Address                                          3666 21st St
# City                                            San Francisco
# State                                                CA 94114
# Country                                                   USA
# Name                                                  Madeira
# Employees   Madeira, 0     8\n1    15\n2    25\n3    10\n4...
# Total data                                                  7
#
#                                                             1  \
# ID                                                          2
# Address                                        735 Dolores St
# City                                            San Francisco
# State                                                CA 94119
# Country                                                   USA
# ...

# %%
df1_t["7"] = [1,"Strada Antica di Andorno","Biella","Piemonte","Italia","EcoMifs",455,7]

# %%
df1_t
# Out:
#                                                             0  \
# ID                                                          1
# Address                                          3666 21st St
# City                                            San Francisco
# State                                                CA 94114
# Country                                                   USA
# Name                                                  Madeira
# Employees   Madeira, 0     8\n1    15\n2    25\n3    10\n4...
# Total data                                                  7
#
#                                                             1  \
# ID                                                          2
# Address                                        735 Dolores St
# City                                            San Francisco
# State                                                CA 94119
# Country                                                   USA
# ...

# %%
df1_t.TCity	State	Country	Name	Employees	Total data
0	1	3666 21st St	San Francisco	CA 94114	USA	Madeira	Madeira, 0 8\n1 15\n2 25\n3 10\n4...	7
1	2	735 Dolores St	San Francisco	CA 94119	USA	Bready Shop	Bready Shop, 0 8\n1 15\n2 25\n3 1...	7
2	3	332 Hill St	San Francisco	California 94114	USA	Super River	Super River, 0 8\n1 15\n2 25\n3 1...	7
3	4	3995 23rd St	San Francisco	CA 94114	USA	Ben's Shop	Ben's Shop, 0 8\n1 15\n2 25\n3 10...	7
4	5	1056 Sanchez St	San Francisco	California	USA	Sanchez	Sanchez, 0 8\n1 15\n2 25\n3 10\n4...	7
5	6	551 Alvarado St	San Francisco	CA 94114	USA	Richvalley	Richvalley, 0 8\n1 15\n2 25\n3 10...	7
7	1	Strada Antica di Andorno	Biella	Piemonte	Italia	EcoMifs	455	7
7	1	Strada Antica di Andorno	Biella	Piemonte	Italia	EcoMifs	455	7
# Out:
#   ID                   Address           City             State Country  \
# 0  1              3666 21st St  San Francisco          CA 94114     USA
# 1  2            735 Dolores St  San Francisco          CA 94119     USA
# 2  3               332 Hill St  San Francisco  California 94114     USA
# 3  4              3995 23rd St  San Francisco          CA 94114     USA
# 4  5           1056 Sanchez St  San Francisco        California     USA
# 5  6           551 Alvarado St  San Francisco          CA 94114     USA
# 7  1  Strada Antica di Andorno         Biella          Piemonte  Italia
# 7  1  Strada Antica di Andorno         Biella          Piemonte  Italia
#
#           Name                                          Employees Total data
# 0      Madeira  Madeira, 0     8\n1    15\n2    25\n3    10\n4...          7
# 1  Bready Shop  Bready Shop, 0     8\n1    15\n2    25\n3    1...          7
# 2  Super River  Super River, 0     8\n1    15\n2    25\n3    1...          7
# ...

# %%
0	1	2	3	4	5	7	7
ID	1	2	3	4	5	6	1	1
Address	3666 21st St	735 Dolores St	332 Hill St	3995 23rd St	1056 Sanchez St	551 Alvarado St	Strada Antica di Andorno	Strada Antica di Andorno
City	San Francisco	San Francisco	San Francisco	San Francisco	San Francisco	San Francisco	Biella	Biella
State	CA 94114	CA 94119	California 94114	CA 94114	California	CA 94114	Piemonte	Piemonte
Country	USA	USA	USA	USA	USA	USA	Italia	Italia
Name	Madeira	Bready Shop	Super River	Ben's Shop	Sanchez	Richvalley	EcoMifs	EcoMifs
Employees	Madeira, 0 8\n1 15\n2 25\n3 10\n4...	Bready Shop, 0 8\n1 15\n2 25\n3 1...	Super River, 0 8\n1 15\n2 25\n3 1...	Ben's Shop, 0 8\n1 15\n2 25\n3 10...	Sanchez, 0 8\n1 15\n2 25\n3 10\n4...	Richvalley, 0 8\n1 15\n2 25\n3 10...	455	455
Total data	7	7	7	7	7	7	7	7
# Out:
#   File "<ipython-input-31-79498f3427c8>", line 1
#     0	1	2	3	4	5	7	7
#      	^
# SyntaxError: invalid syntax
