# %%
import pandas
df = pandas.read_csv("DataForTesting/supermarkets.csv")

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Complete Location info"] = df["Address"] + ", " + df["City"] + ", " + df["State"] + ", " + df["Country"]

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                             Complete Location info
# 0          8         3666 21st St, San Francisco, CA 94114, USA
# 1         15       735 Dolores St, San Francisco, CA 94119, USA
# 2         25  332 Hill St, San Francisco, California 94114, USA
# 3         10         3995 23rd St, San Francisco, CA 94114, USA
# 4         12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df_t = df.T

# %%
df_t
# Out:
#                                                                  0  \
# ID                                                               1
# Address                                               3666 21st St
# City                                                 San Francisco
# State                                                     CA 94114
# Country                                                        USA
# Name                                                       Madeira
# Employees                                                        8
# Complete Location info  3666 21st St, San Francisco, CA 94114, USA
#
#                                                                    1  \
# ID                                                                 2
# Address                                               735 Dolores St
# City                                                   San Francisco
# State                                                       CA 94119
# ...

# %%
df_t[6] = [7, "261 Columbus Ave North Beach","San Francisco","CA 94133-4586","USA","City Lights Booksellers",10,"261 Columbus Ave North Beach, San Francisco, CA 94133-4586, USA"]

# %%
df_t
# Out:
#                                                                  0  \
# ID                                                               1
# Address                                               3666 21st St
# City                                                 San Francisco
# State                                                     CA 94114
# Country                                                        USA
# Name                                                       Madeira
# Employees                                                        8
# Complete Location info  3666 21st St, San Francisco, CA 94114, USA
#
#                                                                    1  \
# ID                                                                 2
# Address                                               735 Dolores St
# City                                                   San Francisco
# State                                                       CA 94119
# ...

# %%
df = df_t.T

# %%
df
# Out:
#   ID                       Address           City             State Country  \
# 0  1                  3666 21st St  San Francisco          CA 94114     USA
# 1  2                735 Dolores St  San Francisco          CA 94119     USA
# 2  3                   332 Hill St  San Francisco  California 94114     USA
# 3  4                  3995 23rd St  San Francisco          CA 94114     USA
# 4  5               1056 Sanchez St  San Francisco        California     USA
# 5  6               551 Alvarado St  San Francisco          CA 94114     USA
# 6  7  261 Columbus Ave North Beach  San Francisco     CA 94133-4586     USA
#
#                       Name Employees  \
# 0                  Madeira         8
# 1              Bready Shop        15
# 2              Super River        25
# 3               Ben's Shop        10
# 4                  Sanchez        12
# 5               Richvalley        20
# 6  City Lights Booksellers        10
#
# ...

# %%
df.iloc[4:6,1:4]
# Out:
#            Address           City       State
# 4  1056 Sanchez St  San Francisco  California
# 5  551 Alvarado St  San Francisco    CA 94114

# %%
list(df.iloc[4:6,1:4])
# Out:
# ['Address', 'City', 'State']

# %%
df["Address"]
# Out:
# 0                    3666 21st St
# 1                  735 Dolores St
# 2                     332 Hill St
# 3                    3995 23rd St
# 4                 1056 Sanchez St
# 5                 551 Alvarado St
# 6    261 Columbus Ave North Beach
# Name: Address, dtype: object

# %%
df.loc[5:,"City":]
# Out:
#             City          State Country                     Name Employees  \
# 5  San Francisco       CA 94114     USA               Richvalley        20
# 6  San Francisco  CA 94133-4586     USA  City Lights Booksellers        10
#
#                               Complete Location info
# 5      551 Alvarado St, San Francisco, CA 94114, USA
# 6  261 Columbus Ave North Beach, San Francisco, C...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-52fc4dc4d6fc> in <module>
# ----> 1 df.shape(1)
#
# TypeError: 'tuple' object is not callable

# %%
df.shape[1]
# Out:
# 8

# %%
df.shape[]
# Out:
#   File "<ipython-input-23-973b942e62b2>", line 1
#     df.shape[]
#              ^
# SyntaxError: invalid syntax

# %%
df.shape[0]
# Out:
# 7

# %%
from geopy.geocoders import ArcGIS

# %%
n = ArcGIS()

# %%
loc = n.geocode("Strada Antica di Andorno, Biella, 13900")

# %%
loc
# Out:
# Location(Strada Antica di Andorno, 13900, Biella, (45.57778410311704, 8.05452589874539, 0.0))

# %%
loc.Address
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-03c4c16e7280> in <module>
# ----> 1 loc.Address
#
# AttributeError: 'Location' object has no attribute 'Address'

# %%
help(loc)
# Out:
# Help on Location in module geopy.location object:
#
# class Location(builtins.object)
#  |  Location(address='', point=None, raw=None)
#  |
#  |  Contains a parsed geocoder response. Can be iterated over as
#  |  ``(location<String>, (latitude<float>, longitude<Float))``.
#  |  Or one can access the properties ``address``, ``latitude``,
#  |  ``longitude``, or ``raw``. The last
#  |  is a dictionary of the geocoder's response for this item.
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __getitem__(self, index)
#  |      Backwards compatibility with geopy<0.98 tuples.
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self, address='', point=None, raw=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |
#  |  __len__(self)
#  |
#  |  __ne__(self, other)
#  |      Return self!=value.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
# ...

# %%
loc.address
# Out:
# 'Strada Antica di Andorno, 13900, Biella'

# %%
df
# Out:
#   ID                       Address           City             State Country  \
# 0  1                  3666 21st St  San Francisco          CA 94114     USA
# 1  2                735 Dolores St  San Francisco          CA 94119     USA
# 2  3                   332 Hill St  San Francisco  California 94114     USA
# 3  4                  3995 23rd St  San Francisco          CA 94114     USA
# 4  5               1056 Sanchez St  San Francisco        California     USA
# 5  6               551 Alvarado St  San Francisco          CA 94114     USA
# 6  7  261 Columbus Ave North Beach  San Francisco     CA 94133-4586     USA
#
#                       Name Employees  \
# 0                  Madeira         8
# 1              Bready Shop        15
# 2              Super River        25
# 3               Ben's Shop        10
# 4                  Sanchez        12
# 5               Richvalley        20
# 6  City Lights Booksellers        10
#
# ...

# %%
df.drop("Coordinates",1)
# Out:
#   ID                       Address           City             State Country  \
# 0  1                  3666 21st St  San Francisco          CA 94114     USA
# 1  2                735 Dolores St  San Francisco          CA 94119     USA
# 2  3                   332 Hill St  San Francisco  California 94114     USA
# 3  4                  3995 23rd St  San Francisco          CA 94114     USA
# 4  5               1056 Sanchez St  San Francisco        California     USA
# 5  6               551 Alvarado St  San Francisco          CA 94114     USA
# 6  7  261 Columbus Ave North Beach  San Francisco     CA 94133-4586     USA
#
#                       Name Employees  \
# 0                  Madeira         8
# 1              Bready Shop        15
# 2              Super River        25
# 3               Ben's Shop        10
# 4                  Sanchez        12
# 5               Richvalley        20
# 6  City Lights Booksellers        10
#
# ...

# %%
df
# Out:
#   ID                       Address           City             State Country  \
# 0  1                  3666 21st St  San Francisco          CA 94114     USA
# 1  2                735 Dolores St  San Francisco          CA 94119     USA
# 2  3                   332 Hill St  San Francisco  California 94114     USA
# 3  4                  3995 23rd St  San Francisco          CA 94114     USA
# 4  5               1056 Sanchez St  San Francisco        California     USA
# 5  6               551 Alvarado St  San Francisco          CA 94114     USA
# 6  7  261 Columbus Ave North Beach  San Francisco     CA 94133-4586     USA
#
#                       Name Employees  \
# 0                  Madeira         8
# 1              Bready Shop        15
# 2              Super River        25
# 3               Ben's Shop        10
# 4                  Sanchez        12
# 5               Richvalley        20
# 6  City Lights Booksellers        10
#
# ...

# %%
df.drop("Coordinates",1,inplace=True)

# %%
df
# Out:
#   ID                       Address           City             State Country  \
# 0  1                  3666 21st St  San Francisco          CA 94114     USA
# 1  2                735 Dolores St  San Francisco          CA 94119     USA
# 2  3                   332 Hill St  San Francisco  California 94114     USA
# 3  4                  3995 23rd St  San Francisco          CA 94114     USA
# 4  5               1056 Sanchez St  San Francisco        California     USA
# 5  6               551 Alvarado St  San Francisco          CA 94114     USA
# 6  7  261 Columbus Ave North Beach  San Francisco     CA 94133-4586     USA
#
#                       Name Employees  \
# 0                  Madeira         8
# 1              Bready Shop        15
# 2              Super River        25
# 3               Ben's Shop        10
# 4                  Sanchez        12
# 5               Richvalley        20
# 6  City Lights Booksellers        10
#
# ...

# %%
df["Latitude"] = df["Address"].apply(n.geocode).apply(lambda x: x.latitude)

# %%
df["Longitude"] = df["Address"].apply(n.geocode).apply(lambda x: x.longitude)

# %%
df
# Out:
#   ID                       Address           City             State Country  \
# 0  1                  3666 21st St  San Francisco          CA 94114     USA
# 1  2                735 Dolores St  San Francisco          CA 94119     USA
# 2  3                   332 Hill St  San Francisco  California 94114     USA
# 3  4                  3995 23rd St  San Francisco          CA 94114     USA
# 4  5               1056 Sanchez St  San Francisco        California     USA
# 5  6               551 Alvarado St  San Francisco          CA 94114     USA
# 6  7  261 Columbus Ave North Beach  San Francisco     CA 94133-4586     USA
#
#                       Name Employees  \
# 0                  Madeira         8
# 1              Bready Shop        15
# 2              Super River        25
# 3               Ben's Shop        10
# 4                  Sanchez        12
# 5               Richvalley        20
# 6  City Lights Booksellers        10
#
# ...

# %%
df_manual = {"Nome":["Marco","Luigi","Giorgio"],"Cognome":["Sarli","Guadagnuolo","Ferragni"]}

# %%
df_manual
# Out:
# {'Nome': ['Marco', 'Luigi', 'Giorgio'],
#  'Cognome': ['Sarli', 'Guadagnuolo', 'Ferragni']}

# %%
df_manual.values()
# Out:
# dict_values([['Marco', 'Luigi', 'Giorgio'], ['Sarli', 'Guadagnuolo', 'Ferragni']])
